# %%
import pandas as pd
gene_data = pd.read_csv('ITG.csv', index_col=0, sep=';')

# %%
gene_data.head()
# Out:
#        TCGA-2E-A9G8-01A  TCGA-4E-A92E-01A  TCGA-5B-A90C-01A  TCGA-5S-A9Q8-01A  \
# Gene
# ITGA1          9.226412         12.371232         11.629812         11.649256
# ITGA2          5.781360         11.333714         13.192601          7.169925
# ITGA3         11.984062         12.296056         11.563196          9.355351
# ITGA4          7.348728         10.319672          9.209453          7.686501
# ITGA5          9.831307         11.249113         11.596656          8.717676
#
#        TCGA-A5-A0G1-01A  TCGA-A5-A0G2-01A  TCGA-A5-A0G3-01A  TCGA-A5-A0G5-01A  \
# Gene
# ITGA1          9.851749          9.167418          6.375039          9.693487
# ITGA2          8.784635          6.321928          6.442943          6.392317
# ITGA3         14.180220         13.294621         12.800496         12.099677
# ITGA4          8.303781          7.569856          4.584963          8.543032
# ITGA5          9.845490         12.397140          8.933691         11.092096
#
# ...
